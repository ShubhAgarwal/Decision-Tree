# %% [markdown]
# # Decision Tree Regressor

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.datasets import load_diabetes

# %% [markdown]
# ## Importing Data

# %%
data = pd.read_csv("ex1data1.txt", header=None)

# %%
data
# Out:
#           0         1
# 0    6.1101  17.59200
# 1    5.5277   9.13020
# 2    8.5186  13.66200
# 3    7.0032  11.85400
# 4    5.8598   6.82330
# ..      ...       ...
# 92   5.8707   7.20290
# 93   5.3054   1.98690
# 94   8.2934   0.14454
# 95  13.3940   9.05510
# 96   5.4369   0.61705
#
# [97 rows x 2 columns]

# %%
x = data[0].to_numpy().reshape(-1,1)
y = data[1].to_numpy().reshape(-1,1)

# %%
plt.plot(x, y, 'r+')
plt.show()

# %% [markdown]
# ## Training Decision Tree

# %%
regressor = DecisionTreeRegressor(max_depth=2)
regressor.fit(x, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=2, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %% [markdown]
# ## Visualizing Decision Tree

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(10, 4))
plot_tree(regressor, filled=True)
plt.show()

# %% [markdown]
# ## Visualizing Dataset and Decision Boundaries

# %%
plt.plot(x, y, 'r+')
plt.xlabel("x")
plt.ylabel("y")
plt.plot([4.5, 8.284], [3.426, 3.426], "k-", linewidth=2)
plt.plot([8.284, 12.268], [7.635, 7.635], "k-", linewidth=2)
plt.plot([12.268, 16.926], [12.487, 12.487], "k-", linewidth=2)
plt.plot([16.926, 23], [20.754, 20.754], "k-", linewidth=2)
plt.plot([12.268, 12.268], [0, 25], "k--", linewidth=2)
plt.plot([8.294, 8.294], [0, 25], "k--", linewidth=2)
plt.plot([16.926, 16.926], [0, 25], "k--", linewidth=2)
plt.show()
